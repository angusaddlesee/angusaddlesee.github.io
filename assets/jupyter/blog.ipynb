# %% [markdown]
# # Sample Jupyter Notebook
#
# This is a sample notebook to demonstrate Jekyll integration with Jupyter notebooks.

# %%
print("Hello from Jupyter!")
# Out:
# Hello from Jupyter!

# %%
# Simple computation
squares = [x**2 for x in range(1, 6)]
squares
# Out:
# [1, 4, 9, 16, 25]
